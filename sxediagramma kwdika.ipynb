# %%
# !python -m spacy download el_core_news_sm
# !pip install dateparser
# !pip install toolz

# %% [markdown]
# ## Website scraping
# - efsyn.gr
# - protothema.gr
# - twitter.com (workbench)
#
# *The code below has been commented out because all scraped data exist as csv files.* *κείμενο σε πλάγια γραφή*

# %%
# import scraper
# scraper.main()

# %% [markdown]
# ## Preprocessing
#
# ### Text preprocessing
# - Related articles section clean-up
# - Removed punctuation
# - Tokenization
# - Stop word removal
# - Stemming
# - Removal of nan values
#
# ### Date preprocessing
# - Added missing timezones
# - Translated to utc timestamp

# %%
import preprocessor
preprocessor.main()
# Out:
# 2021-09-13 19:32:21,425 - [preprocessor] - [INFO] - Started preprocessing 3 csv files
# 2021-09-13 19:33:04,272 - [preprocessor] - [INFO] - Writing results...
# 2021-09-13 19:33:04,302 - [preprocessor] - [INFO] - Preprocessing has completed

# %% [markdown]
# ## Vizualizations
# - wordcloud
# - frequency of top 15 words (bar chart)

# %%
import wordcloud_generator
import generate_frequent_words

wordcloud_generator.main()
generate_frequent_words.main()

# %% [markdown]
# ## Timeseries analysis
# - Articles per week for efsyn.gr
# - Articles per week for protothema.gr
# - Articles per day for twitter.com

# %%
import timeseries_analysis

timeseries_analysis.main()

# %% [markdown]
# ## Sentiment Analysis
# Sentiment analysis using emolex and NRC

# %%
import sentiment_analysis

sentiment_analysis.main()

# %% [markdown]
# ## Cosine similarity
# - heatmap for efsyn.gr
# - heatmap for protothema.gr
# - heatmap for twitter.com

# %%
import cosine_similarity

cosine_similarity.main()
# Out:
# 2021-09-13 19:40:13,041 - [preprocessor] - [INFO] - Started cosine-similary analysis
# 2021-09-13 19:40:13,049 - [preprocessor] - [INFO] - Analyzing tweets
# 2021-09-13 19:40:13,727 - [preprocessor] - [INFO] - Analyzing protothema
# 2021-09-13 19:40:14,385 - [preprocessor] - [INFO] - Analyzing efsyn
# 2021-09-13 19:40:15,102 - [preprocessor] - [INFO] - Sentiment analysis has finished
